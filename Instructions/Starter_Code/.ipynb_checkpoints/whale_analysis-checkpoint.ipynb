# %% [markdown]
# #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("../Resources/whale_returns.csv")
# YOUR CODE HERE
whale = pd.read_csv (whale_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
whale.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833

# %%
# Count nulls
whale.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale = whale.dropna()

whale.isnull().sum()
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("../Resources/algo_returns.csv")
algo = pd.read_csv (algo_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo.head(10)
# YOUR CODE HERE
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# 2014-06-04 -0.001838       NaN
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735

# %%
# Count nulls
algo.isnull().sum()
# YOUR CODE HERE
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo = algo.dropna()
algo.isnull().sum()
# YOUR CODE HERE
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("../Resources/sp500_history.csv")
sp500 = pd.read_csv (sp500_history_csv, index_col="Date", infer_datetime_format = True, parse_dates = True)
#sp500 was given in reverse order, code below fixes that
sp500 = sp500[::-1]
sp500.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500["Close"].dtype
# Out:
# dtype('O')

# %%
# Fix Data Types - Remove $ signs and change from string to float so we can do calculations later
sp500["Close"] = sp500["Close"].str.replace("$", "").astype(float)   
sp500.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate Daily Returns - All portfolios except sp500 were given in daily returns.  Code below calculates daily returns for sp500
sp500["Close"] = sp500["Close"].pct_change()

# %%
# Drop nulls
sp500 = sp500.dropna()

sp500.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename Column

sp500 = sp500.rename(columns={"Close":"SP500"})
sp500.head()
# Out:
#                SP500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
all_portfolios = pd.concat([whale,algo,sp500],axis="columns", join="inner")
#Rename Columns for readability, especially when plotting where longer names cause problems
all_portfolios = all_portfolios.rename(columns = {"SOROS FUND MANAGEMENT LLC": "Soros", "PAULSON & CO.INC." : "Paulson", "TIGER GLOBAL MANAGEMENT LLC" : "Tiger", "BERKSHIRE HATHAWAY INC": "Berkshire", "Algo 1" : "Algo_1","Algo 2": "Algo_2"})
#For some reason the rename function above does not work on Paulson, assume because of the "&" or ".".  Used line below to reference by index
all_portfolios.columns.values[1] = "Paulson"
all_portfolios.head()
# Out:
#                Soros   Paulson     Tiger  Berkshire    Algo_1    Algo_2  \
# Date
# 2015-03-03 -0.001266 -0.004981 -0.000496  -0.006569 -0.001942 -0.000949
# 2015-03-04  0.002230  0.003241 -0.002534   0.004213 -0.008589  0.002416
# 2015-03-05  0.004016  0.004076  0.002355   0.006726 -0.000955  0.004323
# 2015-03-06 -0.007905 -0.003574 -0.008481  -0.013098 -0.004957 -0.011460
# 2015-03-09  0.000582  0.004225  0.005843  -0.001652 -0.005447  0.001303
#
#                SP500
# Date
# 2015-03-03 -0.004539
# 2015-03-04 -0.004389
# 2015-03-05  0.001196
# 2015-03-06 -0.014174
# 2015-03-09  0.003944

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns.

# %%
# Plot daily returns
all_portfolios.plot(figsize=(20,10),title='Daily Returns',fontsize = 15)

# %%
# Plot cumulative returns
all_portfolios_cumulative = (1 + all_portfolios).cumprod() - 1
all_portfolios_cumulative.plot(figsize = (20,12),title = 'Cumulative Portfolio Returns',fontsize = 15)
#all_portfolios_cumulative

# %% [markdown]
# ---

# %% [markdown]
# ## Performance by Month and Year
#
# Analyze the performance by Month and Year:
#
# 1. Calculate the Annual Returns
# 2. Sort the 2017 portfolio returns in descending order to determine the best portfolios for 2017
# 3. Calculate the Monthly Returns
# 4. Sort in descending order, the porfolio returns for December 2018

# %%
# Returns by Year
#I chose to use the resample function instead of groupby.  I am getting different values
#from my classmates (especially on monthly returns), want to better understand why this is happening.

annual_returns = all_portfolios.resample('Y').apply(lambda x: (1+x).cumprod() -1)
annual_returns = annual_returns.resample('Y').last()
annual_returns

#chose not to use code below, don't like the readability, but not 100% sure I am getting the right values with resample

#annual_returns = ((1 + all_portfolios_cumulative).cumprod()) - 1 
#all_portfolios_yearly = all_portfolios.groupby([all_portfolios.index.year]).apply(lambda x: (1+x).cumprod() -1)
#annual_returns = all_portfolios_yearly.groupby(all_portfolios_yearly.index.year).last()
#annual_resample.last()
# Out:
#                Soros   Paulson     Tiger  Berkshire    Algo_1    Algo_2  \
# Date
# 2015-12-31 -0.003019 -0.023685  0.027644   0.034440  0.233385 -0.065759
# 2016-12-31 -0.006991 -0.119136  0.278194  -0.114539  0.169350  0.113744
# 2017-12-31  0.144073 -0.069746 -0.000498   0.491562 -0.003228  0.162514
# 2018-12-31 -0.143357 -0.111315 -0.317783  -0.128091  0.165843 -0.141432
# 2019-12-31  0.200247  0.096603 -0.038493   0.304057  0.154337  0.222163
#
#                SP500
# Date
# 2015-12-31 -0.034689
# 2016-12-31  0.095350
# 2017-12-31  0.194200
# 2018-12-31 -0.062373
# 2019-12-31  0.170265

# %%
# Top Portfolio returns for 2017
returns_2017 = annual_returns.loc['2017-12-31'].sort_values(ascending = False)
returns_2017
# Out:
# Berkshire    0.491562
# SP500        0.194200
# Algo_2       0.162514
# Soros        0.144073
# Tiger       -0.000498
# Algo_1      -0.003228
# Paulson     -0.069746
# Name: 2017-12-31 00:00:00, dtype: float64

# %%
# Returns by Month
returns_by_month = all_portfolios.resample('M').apply(lambda x: (1+x).cumprod() -1)
returns_by_month = returns_by_month.resample('M').last()
returns_by_month.head()
# Out:
#                Soros   Paulson     Tiger  Berkshire    Algo_1    Algo_2  \
# Date
# 2015-03-31  0.017207  0.011306  0.009419   0.002310  0.012788 -0.000962
# 2015-04-30  0.003248  0.016876  0.010373   0.011927 -0.007167  0.009620
# 2015-05-31  0.008094  0.019797 -0.001410   0.001002  0.009439  0.000920
# 2015-06-30 -0.020352 -0.011427 -0.023138  -0.020195 -0.003230 -0.009999
# 2015-07-31 -0.014779 -0.018293  0.020172  -0.021668 -0.051560 -0.016582
#
#                SP500
# Date
# 2015-03-31 -0.023378
# 2015-04-30  0.008521
# 2015-05-31  0.010491
# 2015-06-30 -0.021012
# 2015-07-31  0.019742

# %%
# Top Portfolio Returns for December 2018
dec_2018_returns = returns_by_month.loc['2018-12-31'].sort_values(ascending=False)
dec_2018_returns
# Out:
# Algo_1      -0.055161
# Berkshire   -0.089757
# Paulson     -0.091320
# SP500       -0.091777
# Soros       -0.095657
# Algo_2      -0.119221
# Tiger       -0.144032
# Name: 2018-12-31 00:00:00, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
#Took a long time to understand how to change the figsize of a Seaborn boxplot. Still not sure I understand the syntax
sns.set(rc={'figure.figsize':(12,8)})
all_box = sns.boxplot(data=all_portfolios)

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. Which portfolios are riskier than the S&P 500?
all_std_dev = all_portfolios.std()
all_std_dev = all_std_dev.to_frame()
all_std_dev.columns = ['STD_DEV']
all_std_dev
# YOUR CODE HERE
# Out:
#             STD_DEV
# Soros      0.007895
# Paulson    0.007023
# Tiger      0.010894
# Berkshire  0.012919
# Algo_1     0.007620
# Algo_2     0.008342
# SP500      0.008554

# %%
# Determine which portfolios are riskier than the S&P 500
sp500_std_dev = float(all_std_dev.loc['SP500'])
risky_portfolios = all_std_dev[all_std_dev['STD_DEV']>sp500_std_dev].index.tolist() 
print(f'The following portfolios showed more risk for the given period than the SP500: {risky_portfolios}')
# Out:
# The following portfolios showed more risk for the given period than the SP500: ['Tiger', 'Berkshire']

# %%
# Calculate the annualized standard deviation (252 trading days)
annual_std_dev = all_std_dev['STD_DEV'] * np.sqrt(252)
annual_std_dev
# Out:
# Soros        0.125335
# Paulson      0.111488
# Tiger        0.172936
# Berkshire    0.205077
# Algo_1       0.120967
# Algo_2       0.132430
# SP500        0.135786
# Name: STD_DEV, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
# 2. Calcualte the correlation between each stock to determine which portfolios may mimick the S&P 500
# 2. Calculate and plot a 60 day Beta for Berkshire Hathaway Inc compared to the S&&P 500

# %%
# Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
rolling_std_dev = all_portfolios['SP500'].rolling(window=21).std().plot(title = 'Rolling Standard Deviation of SP500')

# %%
# Correlation
corr_all_portfolios = all_portfolios.corr()
corr_all_portfolios
# Out:
#               Soros   Paulson     Tiger  Berkshire    Algo_1    Algo_2  \
# Soros      1.000000  0.699914  0.561243   0.754360  0.321211  0.826873
# Paulson    0.699914  1.000000  0.434479   0.545623  0.268840  0.678152
# Tiger      0.561243  0.434479  1.000000   0.424423  0.164387  0.507414
# Berkshire  0.754360  0.545623  0.424423   1.000000  0.292033  0.688082
# Algo_1     0.321211  0.268840  0.164387   0.292033  1.000000  0.288243
# Algo_2     0.826873  0.678152  0.507414   0.688082  0.288243  1.000000
# SP500      0.837864  0.669732  0.623946   0.751371  0.279494  0.858764
#
#               SP500
# Soros      0.837864
# Paulson    0.669732
# Tiger      0.623946
# Berkshire  0.751371
# Algo_1     0.279494
# Algo_2     0.858764
# SP500      1.000000

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
#I calculated all portfolios betas compared to the SP500.
beta_portfolios = all_portfolios.cov()/all_portfolios['SP500'].var() 
#drop all columns except SP500 since we are only comparing portfolios to that column
beta_portfolios = beta_portfolios[['SP500']]
#rename SP500 column to reflect that values are portfolio betas vs SP500
beta_portfolios.columns=['Portfolio Beta vs SP500']
#Drop SP500 row since it by definition has a beta of 1 vs itself
beta_portfolios = beta_portfolios.drop(['SP500'])

beta_portfolios
# Out:
#            Portfolio Beta vs SP500
# Soros                     0.773375
# Paulson                   0.549886
# Tiger                     0.794653
# Berkshire                 1.134789
# Algo_1                    0.248991
# Algo_2                    0.837535

# %%
berkshire_roll_cov = all_portfolios['Berkshire'].rolling(window=60).cov(all_portfolios['SP500'])
sp500_roll_var = all_portfolios['SP500'].rolling(window=60).var()
berkshire_roll_beta = berkshire_roll_cov/sp500_roll_var
berkshire_roll_beta.plot(figsize=(20,10))
#not sure why the rolling 60 does not appear to be working when plotted

# %% [markdown]
# ### Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rollwing window is to take the exponentially weighted moving average.berkshire_covs is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the `ewm` with a 21 day half-life.

# %%
# (OPTIONAL) YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# Calculate and plot the annualized Sharpe ratios for all portfolios to determine which portfolio has the best performance

# %%
# Annualzied Sharpe Ratios
portfolio_returns  = all_portfolios.mean()*252
sharpe_ratios = portfolio_returns/annual_std_dev
sharpe_ratios
# Out:
# Soros        0.356417
# Paulson     -0.483570
# Tiger       -0.121060
# Berkshire    0.621810
# Algo_1       1.378648
# Algo_2       0.501364
# SP500        0.648267
# dtype: float64

# %% [markdown]
#  plot() these sharpe ratios using a barplot.
#  On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar',figsize=(10,7), title = 'Sharpe Ratios')
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
#Apple

apple_csv_path = Path('../Resources/aapl_historical.csv')

apple_df = pd.read_csv(apple_csv_path, index_col = "Trade DATE", infer_datetime_format = True, parse_dates = True )

apple_df = apple_df.drop(columns='Symbol')
apple_df.columns = ['AAPL']

apple_df.head()
# Out:
#               AAPL
# Trade DATE
# 2019-05-09  200.72
# 2019-05-08  202.90
# 2019-05-07  202.86
# 2019-05-06  208.48
# 2019-05-03  211.75

# %%
# Read the second stock
# Google
google_csv_path = Path('../Resources/goog_historical.csv')

google_df = pd.read_csv(google_csv_path, index_col = "Trade DATE", infer_datetime_format = True, parse_dates = True )

google_df = google_df.drop(columns='Symbol')
google_df.columns = ['GOOG']
google_df.head()
# Out:
#                GOOG
# Trade DATE
# 2019-05-09  1162.38
# 2019-05-08  1166.27
# 2019-05-07  1174.10
# 2019-05-06  1189.39
# 2019-05-03  1185.40

# %%
# Read the third stock
#COSTCO
costco_csv_path = Path('../Resources/cost_historical.csv')

costco_df = pd.read_csv(costco_csv_path, index_col = "Trade DATE", infer_datetime_format = True, parse_dates = True )

costco_df = costco_df.drop(columns='Symbol')
costco_df.columns = ['COST']
costco_df.head()
# Out:
#               COST
# Trade DATE
# 2019-05-09  243.47
# 2019-05-08  241.34
# 2019-05-07  240.18
# 2019-05-06  244.23
# 2019-05-03  244.62

# %%
# Concatenate all stocks into a single DataFrame
my_portfolio = pd.concat([apple_df,google_df,costco_df],axis="columns", join="inner")
my_portfolio = my_portfolio[::-1]
my_portfolio.head()
# Out:
#               AAPL     GOOG    COST
# Trade DATE
# 2018-05-11  188.59  1098.26  195.76
# 2018-05-14  188.15  1100.20  195.88
# 2018-05-15  186.44  1079.23  195.48
# 2018-05-16  188.18  1081.77  198.71
# 2018-05-17  186.99  1078.59  199.60

# %%
# Reset the index
#my_portfolio.reset_index(inplace=True)

# %%
# Pivot the Data so that the stock tickers are the columns, the dates are the index, and the 
# values are the closing prices
# Don't understand what is being asked here.  I think my dataframe is already set up as needed.

# %%
# Drop Nulls

my_portfolio = my_portfolio.pct_change()
my_portfolio = my_portfolio.dropna()
my_portfolio.head()
# Out:
#                 AAPL      GOOG      COST
# Trade DATE
# 2018-05-14 -0.002333  0.001766  0.000613
# 2018-05-15 -0.009088 -0.019060 -0.002042
# 2018-05-16  0.009333  0.002354  0.016523
# 2018-05-17 -0.006324 -0.002940  0.004479
# 2018-05-18 -0.003637 -0.011339 -0.003206

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
my_portfolio_returns = my_portfolio.dot(weights)
my_portfolio_returns.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
merged_df = pd.concat([all_portfolios,my_portfolio_returns], axis = 1, join='inner')
merged_df.rename(columns={0:'My Portfolio'},inplace=True)
merged_df.head()
# Out:
#                Soros   Paulson     Tiger  Berkshire    Algo_1    Algo_2  \
# 2018-05-14  0.000000  0.000000  0.000000   0.000000  0.000915  0.001635
# 2018-05-15 -0.000726 -0.001409 -0.003189  -0.014606 -0.001135 -0.001139
# 2018-05-16  0.008637  0.006244  0.005480   0.004310 -0.002326  0.003341
# 2018-05-17 -0.001955  0.002524 -0.006267  -0.005140 -0.006949  0.005205
# 2018-05-18 -0.004357 -0.002672 -0.012832  -0.002212  0.002557 -0.002496
#
#                SP500  My Portfolio
# 2018-05-14  0.000884      0.000015
# 2018-05-15 -0.006842     -0.010064
# 2018-05-16  0.004061      0.009403
# 2018-05-17 -0.000856     -0.001595
# 2018-05-18 -0.002632     -0.006061

# %%
# Only compare dates where the new, custom portfolio has dates
#Not sure what to do on this step
merged_df.dropna()
merged_df.head()
# Out:
#                Soros   Paulson     Tiger  Berkshire    Algo_1    Algo_2  \
# 2018-05-14  0.000000  0.000000  0.000000   0.000000  0.000915  0.001635
# 2018-05-15 -0.000726 -0.001409 -0.003189  -0.014606 -0.001135 -0.001139
# 2018-05-16  0.008637  0.006244  0.005480   0.004310 -0.002326  0.003341
# 2018-05-17 -0.001955  0.002524 -0.006267  -0.005140 -0.006949  0.005205
# 2018-05-18 -0.004357 -0.002672 -0.012832  -0.002212  0.002557 -0.002496
#
#                SP500  My Portfolio
# 2018-05-14  0.000884      0.000015
# 2018-05-15 -0.006842     -0.010064
# 2018-05-16  0.004061      0.009403
# 2018-05-17 -0.000856     -0.001595
# 2018-05-18 -0.002632     -0.006061

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
merged_std_dev = merged_df.std()
merged_std_dev = merged_std_dev.to_frame()
merged_std_dev.columns = ['STD_DEV']
merged_std_dev
# Out:
#                STD_DEV
# Soros         0.009240
# Paulson       0.007353
# Tiger         0.014648
# Berkshire     0.015569
# Algo_1        0.008423
# Algo_2        0.008791
# SP500         0.009578
# My Portfolio  0.013323

# %%
# Rolling
merged_rolling_std_dev = merged_df.rolling(window=21).std().plot(title = 'Rolling Standard Deviation of All Portfolios')

# %%
# Beta
beta_my_portfolio = merged_df['My Portfolio'].cov(merged_df['SP500'])/merged_df['SP500'].var() 
print(f'The beta of my portfolio vs the SP500 is: {beta_my_portfolio}')
# Out:
# The beta of my portfolio vs the SP500 is: 1.2127120076458702

# %%
# Annualzied Sharpe Ratios
merged_portfolio_returns  = merged_df.mean()*252
#annual std_dev
merged_annual_std_dev = merged_std_dev['STD_DEV'] * np.sqrt(252)
#annual sharpe
merged_sharpe_ratios = merged_portfolio_returns/annual_std_dev
merged_sharpe_ratios
# Out:
# Soros           0.430713
# Paulson         0.258738
# Tiger          -1.034216
# Berkshire       0.159756
# Algo_1          2.035665
# Algo_2          0.080607
# SP500           0.584820
# My Portfolio    0.933123
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
merged_sharpe_ratios.plot(kind='bar',figsize=(12,10))

# %% [markdown]
# ## Include correlation analysis to determine which stocks (if any) are correlated

# %%
corr_merged = merged_df.corr()
corr_merged
# Out:
#                  Soros   Paulson     Tiger  Berkshire    Algo_1    Algo_2  \
# Soros         1.000000  0.791962  0.478627   0.816675  0.337826  0.862846
# Paulson       0.791962  1.000000  0.485375   0.650758  0.361301  0.783656
# Tiger         0.478627  0.485375  1.000000   0.325457  0.114554  0.409496
# Berkshire     0.816675  0.650758  0.325457   1.000000  0.327000  0.782804
# Algo_1        0.337826  0.361301  0.114554   0.327000  1.000000  0.365512
# Algo_2        0.862846  0.783656  0.409496   0.782804  0.365512  1.000000
# SP500         0.876981  0.766680  0.481030   0.852303  0.289358  0.875721
# My Portfolio  0.733250  0.644210  0.391972   0.801158  0.261471  0.739936
#
#                  SP500  My Portfolio
# Soros         0.876981      0.733250
# Paulson       0.766680      0.644210
# Tiger         0.481030      0.391972
# Berkshire     0.852303      0.801158
# Algo_1        0.289358      0.261471
# Algo_2        0.875721      0.739936
# ...

# %%
#heatmap to visualize correlations
sns.heatmap(corr_merged, vmin=-1, vmax=1)

# %% [markdown]
# #Correlation Analysis
# The dark squares indicate portfolios with low correlations.  We can see that Algo_1 and Tiger have the lowest correlations with other portfolios. Because Algo_1 also has the highest sharpe ratio, it has the overall most positive impact if we were to make a portfolio of portfolios.
